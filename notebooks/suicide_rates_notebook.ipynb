# %%
import pandas as pd

# %%
import numpy as np

# %%
s = pd.Series([1,2,3])

# %%
s
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
df = pd.read_csv('data/raw/crude_suicide_rates.csv')

# %%
df
# Out:
#          Country          Sex   80_above   70to79   60to69    50to59   \
# 0    Afghanistan   Both sexes       42.0     11.0       5.5       5.6
# 1    Afghanistan         Male       70.4     20.9       9.8       9.3
# 2    Afghanistan       Female       20.1      2.3       1.4       1.6
# 3        Albania   Both sexes       16.3      8.3       6.0       7.8
# 4        Albania         Male       23.2     11.9       8.1      11.4
# ..           ...          ...        ...      ...       ...       ...
# 544       Zambia         Male      152.1     79.0      38.7      27.3
# 545       Zambia       Female       31.2     26.4      16.0      11.2
# 546     Zimbabwe   Both sexes      205.7     81.5      41.3      29.4
# 547     Zimbabwe         Male      285.0    111.5      62.8      47.0
# 548     Zimbabwe       Female      152.4     59.4      26.4      16.0
#
#       40to49   30to39   20to29   10to19
# 0        6.6      9.2     10.2      3.1
# 1       10.5     15.1     16.3      4.8
# ...

# %%
df.dtypes
# Out:
# Country       object
# Sex           object
#  80_above    float64
#  70to79      float64
#  60to69      float64
#  50to59      float64
#  40to49      float64
#  30to39      float64
#  20to29      float64
#  10to19      float64
# dtype: object

# %%
df.head()
# Out:
#        Country          Sex   80_above   70to79   60to69    50to59    40to49  \
# 0  Afghanistan   Both sexes       42.0     11.0       5.5       5.6      6.6
# 1  Afghanistan         Male       70.4     20.9       9.8       9.3     10.5
# 2  Afghanistan       Female       20.1      2.3       1.4       1.6      2.3
# 3      Albania   Both sexes       16.3      8.3       6.0       7.8      9.1
# 4      Albania         Male       23.2     11.9       8.1      11.4     13.5
#
#     30to39   20to29   10to19
# 0      9.2     10.2      3.1
# 1     15.1     16.3      4.8
# 2      2.7      3.5      1.2
# 3      6.1      6.5      5.0
# 4      8.8      6.3      3.1

# %%
df.index
# Out:
# RangeIndex(start=0, stop=549, step=1)

# %%
df.columns
# Out:
# Index(['Country', 'Sex', ' 80_above', ' 70to79', ' 60to69 ', ' 50to59 ',
#        ' 40to49', ' 30to39', ' 20to29', ' 10to19'],
#       dtype='object')

# %%
df.to_numpy()
# Out:
# array([['Afghanistan', ' Both sexes', 42.0, ..., 9.2, 10.2, 3.1],
#        ['Afghanistan', ' Male', 70.4, ..., 15.1, 16.3, 4.8],
#        ['Afghanistan', ' Female', 20.1, ..., 2.7, 3.5, 1.2],
#        ...,
#        ['Zimbabwe', ' Both sexes', 205.7, ..., 13.7, 11.3, 4.6],
#        ['Zimbabwe', ' Male', 285.0, ..., 22.8, 19.1, 6.4],
#        ['Zimbabwe', ' Female', 152.4, ..., 5.5, 3.8, 2.7]], dtype=object)

# %%
df.describe()
# Out:
#          80_above      70to79     60to69      50to59       40to49      30to39  \
# count  549.000000  549.000000  549.000000  549.000000  549.000000  549.000000
# mean    42.585428   25.936794   17.439162   14.743352   12.189435   10.895446
# std     43.477900   24.795457   14.315504   12.790041   11.121364   10.148280
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%     13.600000    8.400000    6.600000    5.600000    4.800000    4.300000
# 50%     26.600000   17.100000   12.900000   11.200000    9.000000    8.000000
# 75%     55.500000   35.800000   24.000000   20.000000   16.400000   13.900000
# max    285.000000  133.700000   78.500000   85.400000   86.500000   88.400000
#
#            20to29      10to19
# count  549.000000  549.000000
# mean    10.423315    4.075046
# std      9.051273    3.393507
# min      0.000000    0.000000
# 25%      4.300000    1.700000
# 50%      7.900000    3.100000
# 75%     13.500000    5.300000
# ...

# %%
df.T
# Out:
#                    0            1            2            3        4    \
# Country    Afghanistan  Afghanistan  Afghanistan      Albania  Albania
# Sex         Both sexes         Male       Female   Both sexes     Male
#  80_above           42         70.4         20.1         16.3     23.2
#  70to79             11         20.9          2.3          8.3     11.9
#  60to69            5.5          9.8          1.4            6      8.1
#  50to59            5.6          9.3          1.6          7.8     11.4
#  40to49            6.6         10.5          2.3          9.1     13.5
#  30to39            9.2         15.1          2.7          6.1      8.8
#  20to29           10.2         16.3          3.5          6.5      6.3
#  10to19            3.1          4.8          1.2            5      3.1
#
#                5            6        7        8            9    ...       539  \
# Country    Albania      Algeria  Algeria  Algeria       Angola  ...  Viet Nam
# ...

# %%
df
# Out:
#          Country          Sex   80_above   70to79   60to69    50to59   \
# 0    Afghanistan   Both sexes       42.0     11.0       5.5       5.6
# 1    Afghanistan         Male       70.4     20.9       9.8       9.3
# 2    Afghanistan       Female       20.1      2.3       1.4       1.6
# 3        Albania   Both sexes       16.3      8.3       6.0       7.8
# 4        Albania         Male       23.2     11.9       8.1      11.4
# ..           ...          ...        ...      ...       ...       ...
# 544       Zambia         Male      152.1     79.0      38.7      27.3
# 545       Zambia       Female       31.2     26.4      16.0      11.2
# 546     Zimbabwe   Both sexes      205.7     81.5      41.3      29.4
# 547     Zimbabwe         Male      285.0    111.5      62.8      47.0
# 548     Zimbabwe       Female      152.4     59.4      26.4      16.0
#
#       40to49   30to39   20to29   10to19
# 0        6.6      9.2     10.2      3.1
# 1       10.5     15.1     16.3      4.8
# ...

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#              Sex      Country   80_above   70to79   60to69    50to59   \
# 0     Both sexes  Afghanistan       42.0     11.0       5.5       5.6
# 1           Male  Afghanistan       70.4     20.9       9.8       9.3
# 2         Female  Afghanistan       20.1      2.3       1.4       1.6
# 3     Both sexes      Albania       16.3      8.3       6.0       7.8
# 4           Male      Albania       23.2     11.9       8.1      11.4
# ..           ...          ...        ...      ...       ...       ...
# 544         Male       Zambia      152.1     79.0      38.7      27.3
# 545       Female       Zambia       31.2     26.4      16.0      11.2
# 546   Both sexes     Zimbabwe      205.7     81.5      41.3      29.4
# 547         Male     Zimbabwe      285.0    111.5      62.8      47.0
# 548       Female     Zimbabwe      152.4     59.4      26.4      16.0
#
#       40to49   30to39   20to29   10to19
# 0        6.6      9.2     10.2      3.1
# 1       10.5     15.1     16.3      4.8
# ...

# %%
df.sort_values(by='Country', ascending=False)
# Out:
#          Country          Sex   80_above   70to79   60to69    50to59   \
# 548     Zimbabwe       Female      152.4     59.4      26.4      16.0
# 547     Zimbabwe         Male      285.0    111.5      62.8      47.0
# 546     Zimbabwe   Both sexes      205.7     81.5      41.3      29.4
# 545       Zambia       Female       31.2     26.4      16.0      11.2
# 544       Zambia         Male      152.1     79.0      38.7      27.3
# ..           ...          ...        ...      ...       ...       ...
# 3        Albania   Both sexes       16.3      8.3       6.0       7.8
# 5        Albania       Female       10.9      4.9       3.9       4.4
# 2    Afghanistan       Female       20.1      2.3       1.4       1.6
# 1    Afghanistan         Male       70.4     20.9       9.8       9.3
# 0    Afghanistan   Both sexes       42.0     11.0       5.5       5.6
#
#       40to49   30to39   20to29   10to19
# 548      9.4      5.5      3.8      2.7
# 547     30.1     22.8     19.1      6.4
# ...

# %%
df[df['Country'].isin(['United Kingdom of Great Britain and Northern Ireland'])]
# Out:
#                                                Country          Sex  \
# 516  United Kingdom of Great Britain and Northern I...   Both sexes
# 517  United Kingdom of Great Britain and Northern I...         Male
# 518  United Kingdom of Great Britain and Northern I...       Female
#
#       80_above   70to79   60to69    50to59    40to49   30to39   20to29  \
# 516       15.4      7.4       8.5      13.4     15.0     10.8      8.6
# 517       19.7     11.3      13.0      20.8     24.0     16.7     13.4
# 518       12.6      3.9       4.2       6.2      6.1      4.9      3.5
#
#       10to19
# 516      2.2
# 517      3.2
# 518      1.2

# %%
df.iat[0,1] = ' Both sexes'

# %%
df.mean()
# Out:
#  80_above    42.585428
#  70to79      25.936794
#  60to69      17.439162
#  50to59      14.743352
#  40to49      12.189435
#  30to39      10.895446
#  20to29      10.423315
#  10to19       4.075046
# dtype: float64

# %%
df.isnull()
# Out:
#      Country    Sex   80_above   70to79   60to69    50to59    40to49   30to39  \
# 0      False  False      False    False     False     False    False    False
# 1      False  False      False    False     False     False    False    False
# 2      False  False      False    False     False     False    False    False
# 3      False  False      False    False     False     False    False    False
# 4      False  False      False    False     False     False    False    False
# ..       ...    ...        ...      ...       ...       ...      ...      ...
# 544    False  False      False    False     False     False    False    False
# 545    False  False      False    False     False     False    False    False
# 546    False  False      False    False     False     False    False    False
# 547    False  False      False    False     False     False    False    False
# 548    False  False      False    False     False     False    False    False
#
#       20to29   10to19
# ...

# %%
df.isnull()
# Out:
#      Country    Sex   80_above   70to79   60to69    50to59    40to49   30to39  \
# 0      False  False      False    False     False     False    False    False
# 1      False  False      False    False     False     False    False    False
# 2      False  False      False    False     False     False    False    False
# 3      False  False      False    False     False     False    False    False
# 4      False  False      False    False     False     False    False    False
# ..       ...    ...        ...      ...       ...       ...      ...      ...
# 544    False  False      False    False     False     False    False    False
# 545    False  False      False    False     False     False    False    False
# 546    False  False      False    False     False     False    False    False
# 547    False  False      False    False     False     False    False    False
# 548    False  False      False    False     False     False    False    False
#
#       20to29   10to19
# ...

# %%
df.isnull().sum()
# Out:
# Country      0
# Sex          0
#  80_above    0
#  70to79      0
#  60to69      0
#  50to59      0
#  40to49      0
#  30to39      0
#  20to29      0
#  10to19      0
# dtype: int64

# %%
df2 = pd.read_csv('data/raw/age_standardized_suicide_rates.csv')

# %%
df2
# Out:
#          Country          Sex  2016  2015  2010  2000
# 0    Afghanistan   Both sexes   6.4   6.6   7.4   8.1
# 1    Afghanistan         Male  10.6  10.9  12.5  14.3
# 2    Afghanistan       Female   2.1   2.1   2.1   1.7
# 3        Albania   Both sexes   5.6   5.3   7.7   5.8
# 4        Albania         Male   7.0   6.7   9.5   8.2
# ..           ...          ...   ...   ...   ...   ...
# 544       Zambia         Male  17.5  17.4  17.9  21.9
# 545       Zambia       Female   6.2   6.1   6.2   7.5
# 546     Zimbabwe   Both sexes  19.1  18.9  20.6  21.7
# 547     Zimbabwe         Male  29.1  28.7  32.3  35.5
# 548     Zimbabwe       Female  11.1  11.1  11.1   9.8
#
# [549 rows x 6 columns]

# %%
sr_df = pd.merge(df, df2, on=['Country','Sex'])

# %%
import matplotlib.pyplot as plt

# %%
plt.close('all')

# %%
sr_df.cumsum()
# Out:
#                                                Country  \
# 0                                          Afghanistan
# 1                               AfghanistanAfghanistan
# 2                    AfghanistanAfghanistanAfghanistan
# 3             AfghanistanAfghanistanAfghanistanAlbania
# 4      AfghanistanAfghanistanAfghanistanAlbaniaAlbania
# ..                                                 ...
# 544  AfghanistanAfghanistanAfghanistanAlbaniaAlbani...
# 545  AfghanistanAfghanistanAfghanistanAlbaniaAlbani...
# 546  AfghanistanAfghanistanAfghanistanAlbaniaAlbani...
# 547  AfghanistanAfghanistanAfghanistanAlbaniaAlbani...
# 548  AfghanistanAfghanistanAfghanistanAlbaniaAlbani...
#
#                                                    Sex   80_above   70to79  \
# 0                                           Both sexes       42.0     11.0
# 1                                      Both sexes Male      112.4     31.9
# 2                               Both sexes Male Female      132.5     34.2
# ...

# %%
sr_df.plot()
# Out:
# <AxesSubplot:>

# %%
pd.plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-79-71e37a543e7b> in <module>
# ----> 1 pd.plot()
#
# /usr/local/Cellar/jupyterlab/2.2.6/libexec/lib/python3.8/site-packages/pandas/__init__.py in __getattr__(name)
#     256             return _SparseArray
#     257
# --> 258         raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     259
#     260
#
# AttributeError: module 'pandas' has no attribute 'plot'

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df2.plot()
# Out:
# <AxesSubplot:>

# %%
ts = df.cumsum()

# %%
ts.plot()
# Out:
# <AxesSubplot:>

# %%
grouped_sr_df = sr_df.groupby(['Country', 'Sex'])

# %%
male_df = df[df['Sex'] == ' Male']

# %%
male_df
# Out:
#                                 Country    Sex   80_above   70to79   60to69   \
# 1                           Afghanistan   Male       70.4     20.9       9.8
# 4                               Albania   Male       23.2     11.9       8.1
# 7                               Algeria   Male       12.7      8.4       6.2
# 10                               Angola   Male      123.2     68.2      34.7
# 13                  Antigua and Barbuda   Male        0.0      0.0       0.0
# ..                                  ...    ...        ...      ...       ...
# 535  Venezuela (Bolivarian Republic of)   Male       20.5     12.5      10.3
# 538                            Viet Nam   Male       29.4     26.2      20.6
# 541                               Yemen   Male       18.2     14.2      11.9
# 544                              Zambia   Male      152.1     79.0      38.7
# 547                            Zimbabwe   Male      285.0    111.5      62.8
#
# ...

# %%
female_df = df[df['Sex'] == ' Female']

# %%
female_df.describe()
# Out:
#          80_above      70to79     60to69      50to59       40to49      30to39  \
# count  183.000000  183.000000  183.000000  183.000000  183.000000  183.000000
# mean    23.695082   15.379235    9.971585    7.493443    5.622404    4.963934
# std     27.792527   19.112300   10.261079    6.721726    4.569535    3.780286
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      7.950000    4.650000    3.850000    2.850000    2.550000    2.500000
# 50%     17.100000    9.500000    7.100000    5.900000    4.500000    3.800000
# 75%     27.850000   18.950000   12.600000    9.800000    7.350000    6.400000
# max    210.400000  133.700000   69.900000   56.900000   40.700000   26.900000
#
#            20to29      10to19
# count  183.000000  183.000000
# mean     5.042623    2.843169
# std      4.121431    2.776183
# min      0.000000    0.000000
# 25%      2.550000    1.100000
# 50%      3.800000    2.000000
# 75%      6.400000    3.650000
# ...

# %%
male_df.describe()
# Out:
#          80_above      70to79     60to69      50to59       40to49      30to39  \
# count  183.000000  183.000000  183.000000  183.000000  183.000000  183.000000
# mean    64.504372   37.505464   25.271038   22.149727   18.786339   16.801093
# std     53.640520   28.339366   16.239796   15.635315   13.917073   12.871550
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%     23.050000   14.200000   12.150000   10.600000    9.900000    8.350000
# 50%     44.400000   29.000000   23.200000   18.900000   15.600000   13.700000
# 75%     95.550000   54.800000   34.050000   29.950000   23.950000   21.650000
# max    285.000000  123.200000   78.500000   85.400000   86.500000   88.400000
#
#            20to29      10to19
# count  183.000000  183.000000
# mean    15.726776    5.289071
# std     11.139090    3.884796
# min      0.000000    0.000000
# 25%      8.050000    2.700000
# 50%     12.000000    4.200000
# 75%     20.500000    6.600000
# ...

# %%
male_df.describe().to_csv('data/external/male_describe.csv')

# %%
female_df.describe().to_csv('data/external/female_describe.csv')

# %%
facilities = pd.read_csv('data/raw/Facilities.csv')

# %%
facilities.describe()
# Out:
#          Year  Mental _hospitals  health_units  outpatient _facilities  \
# count   112.0          90.000000    102.000000              100.000000
# mean   2016.0           0.246133      0.319078                1.875130
# std       0.0           0.910416      0.618220                3.227911
# min    2016.0           0.000000      0.006000                0.006000
# 25%    2016.0           0.018250      0.035750                0.123500
# 50%    2016.0           0.036500      0.093500                0.573000
# 75%    2016.0           0.158750      0.379000                2.236000
# max    2016.0           8.314000      4.542000               19.751000
#
#        day _treatment  residential_facilities
# count       51.000000               45.000000
# mean         1.134804                0.873311
# std          2.725713                1.609117
# min          0.002000                0.006000
# 25%          0.022500                0.033000
# 50%          0.125000                0.152000
# ...

# %%
facilities
# Out:
#                  Country  Year  Mental _hospitals  health_units  \
# 0            Afghanistan  2016              0.003         0.012
# 1                Albania  2016              0.068         0.068
# 2                Algeria  2016              0.048         0.068
# 3                 Angola  2016              0.011           NaN
# 4    Antigua and Barbuda  2016              1.001           NaN
# ..                   ...   ...                ...           ...
# 107              Vanuatu  2016                NaN         0.756
# 108             Viet Nam  2016              0.043         0.017
# 109                Yemen  2016              0.033         0.026
# 110               Zambia  2016              0.062         0.062
# 111             Zimbabwe  2016              0.025         0.025
#
#      outpatient _facilities  day _treatment  residential_facilities
# 0                     0.006             NaN                     NaN
# ...

# %%
fc_df = pd.merge(df, facilities, on=['Country'])

# %%
facilities
# Out:
#                  Country  Year  Mental _hospitals  health_units  \
# 0            Afghanistan  2016              0.003         0.012
# 1                Albania  2016              0.068         0.068
# 2                Algeria  2016              0.048         0.068
# 3                 Angola  2016              0.011           NaN
# 4    Antigua and Barbuda  2016              1.001           NaN
# ..                   ...   ...                ...           ...
# 107              Vanuatu  2016                NaN         0.756
# 108             Viet Nam  2016              0.043         0.017
# 109                Yemen  2016              0.033         0.026
# 110               Zambia  2016              0.062         0.062
# 111             Zimbabwe  2016              0.025         0.025
#
#      outpatient _facilities  day _treatment  residential_facilities
# 0                     0.006             NaN                     NaN
# ...

# %%
df
# Out:
#          Country          Sex   80_above   70to79   60to69    50to59   \
# 0    Afghanistan   Both sexes       42.0     11.0       5.5       5.6
# 1    Afghanistan         Male       70.4     20.9       9.8       9.3
# 2    Afghanistan       Female       20.1      2.3       1.4       1.6
# 3        Albania   Both sexes       16.3      8.3       6.0       7.8
# 4        Albania         Male       23.2     11.9       8.1      11.4
# ..           ...          ...        ...      ...       ...       ...
# 544       Zambia         Male      152.1     79.0      38.7      27.3
# 545       Zambia       Female       31.2     26.4      16.0      11.2
# 546     Zimbabwe   Both sexes      205.7     81.5      41.3      29.4
# 547     Zimbabwe         Male      285.0    111.5      62.8      47.0
# 548     Zimbabwe       Female      152.4     59.4      26.4      16.0
#
#       40to49   30to39   20to29   10to19
# 0        6.6      9.2     10.2      3.1
# 1       10.5     15.1     16.3      4.8
# ...

# %%
male_df = df[df['Sex'] == ' Male']

# %%
male_df
# Out:
#                                 Country    Sex   80_above   70to79   60to69   \
# 1                           Afghanistan   Male       70.4     20.9       9.8
# 4                               Albania   Male       23.2     11.9       8.1
# 7                               Algeria   Male       12.7      8.4       6.2
# 10                               Angola   Male      123.2     68.2      34.7
# 13                  Antigua and Barbuda   Male        0.0      0.0       0.0
# ..                                  ...    ...        ...      ...       ...
# 535  Venezuela (Bolivarian Republic of)   Male       20.5     12.5      10.3
# 538                            Viet Nam   Male       29.4     26.2      20.6
# 541                               Yemen   Male       18.2     14.2      11.9
# 544                              Zambia   Male      152.1     79.0      38.7
# 547                            Zimbabwe   Male      285.0    111.5      62.8
#
# ...

# %%
male_df.describe()
# Out:
#          80_above      70to79     60to69      50to59       40to49      30to39  \
# count  183.000000  183.000000  183.000000  183.000000  183.000000  183.000000
# mean    64.504372   37.505464   25.271038   22.149727   18.786339   16.801093
# std     53.640520   28.339366   16.239796   15.635315   13.917073   12.871550
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%     23.050000   14.200000   12.150000   10.600000    9.900000    8.350000
# 50%     44.400000   29.000000   23.200000   18.900000   15.600000   13.700000
# 75%     95.550000   54.800000   34.050000   29.950000   23.950000   21.650000
# max    285.000000  123.200000   78.500000   85.400000   86.500000   88.400000
#
#            20to29      10to19
# count  183.000000  183.000000
# mean    15.726776    5.289071
# std     11.139090    3.884796
# min      0.000000    0.000000
# 25%      8.050000    2.700000
# 50%     12.000000    4.200000
# 75%     20.500000    6.600000
# ...

# %%
male_df.plot()
# Out:
# <AxesSubplot:>

# %%
plt.close('all')

# %%
# Out:
# /usr/local/Cellar/jupyterlab/2.2.6/libexec/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py:1235: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# <AxesSubplot:xlabel='Country'>

# %%
top_five_powers = ['United Kingdom of Great Britain and Northern Ireland', 'France', 'United States of America', 'Russian Federation', 'China']

# %%
top_five_male_df = male_df[male_df['Country'].isin(top_five_powers)]

# %%
top_five_female_df = female_df[female_df['Country'].isin(top_five_powers)]

# %%
top_five_male_df
# Out:
#                                                Country    Sex   80_above  \
# 103                                              China   Male       73.2
# 178                                             France   Male       96.8
# 406                                 Russian Federation   Male      101.0
# 517  United Kingdom of Great Britain and Northern I...   Male       19.7
# 523                           United States of America   Male       49.7
#
#       70to79   60to69    50to59    40to49   30to39   20to29   10to19     mean
# 103     51.2      24.2       9.0      4.8      4.7      4.4      1.5  21.6250
# 178     37.2      28.1      35.0     33.9     20.6     12.0      2.9  33.3125
# 406     76.6      61.4      72.4     70.0     88.4     56.5     11.9  67.2750
# 517     11.3      13.0      20.8     24.0     16.7     13.4      3.2  15.2625
# 523     32.5      27.9      32.0     28.5     29.4     28.9      9.0  29.7375

# %%
top_five_female_df['mean'] = top_five_female_df.mean(axis=1)
# Out:
# <ipython-input-188-d6466e3d5f2d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top_five_female_df['mean'] = top_five_female_df.mean(axis=1)

# %%
top_five_female_df
# Out:
#                                                Country      Sex   80_above  \
# 104                                              China   Female       52.3
# 179                                             France   Female       60.1
# 407                                 Russian Federation   Female       28.4
# 518  United Kingdom of Great Britain and Northern I...   Female       12.6
# 524                           United States of America   Female        9.6
#
#       70to79   60to69    50to59    40to49   30to39   20to29   10to19     mean
# 104     37.1      22.6      12.1      7.8      7.4      5.7      2.3  18.4125
# 179     18.5      13.0      11.8      9.6      5.9      3.9      1.5  15.5375
# 407     15.6       9.8       8.9      9.0     11.5      8.8      4.3  12.0375
# 518      3.9       4.2       6.2      6.1      4.9      3.5      1.2   5.3250
# 524      6.6       8.8      11.6     10.1      9.0      6.6      3.4   8.2125

# %%
## Top Five Super Power Countries Suicide Averages (2016)

# %%
top_five_male_df.plot(x="Country", y="mean", kind="bar")
# Out:
# <AxesSubplot:xlabel='Country'>

# %%
top_five_female_df.plot(x="Country",y="mean", kind="bar")
# Out:
# <AxesSubplot:xlabel='Country'>

# %%
fc_df
# Out:
#          Country          Sex   80_above   70to79   60to69    50to59   \
# 0    Afghanistan   Both sexes       42.0     11.0       5.5       5.6
# 1    Afghanistan         Male       70.4     20.9       9.8       9.3
# 2    Afghanistan       Female       20.1      2.3       1.4       1.6
# 3        Albania   Both sexes       16.3      8.3       6.0       7.8
# 4        Albania         Male       23.2     11.9       8.1      11.4
# ..           ...          ...        ...      ...       ...       ...
# 322       Zambia         Male      152.1     79.0      38.7      27.3
# 323       Zambia       Female       31.2     26.4      16.0      11.2
# 324     Zimbabwe   Both sexes      205.7     81.5      41.3      29.4
# 325     Zimbabwe         Male      285.0    111.5      62.8      47.0
# 326     Zimbabwe       Female      152.4     59.4      26.4      16.0
#
#       40to49   30to39   20to29   10to19  Year  Mental _hospitals  \
# ...

# %%
column_means = fc_df.mean()

# %%
fc_df = fc_df.fillna(column_means)

# %%
## Facilities and Crude Combined Data

# %%
fc_df[fc_df['Country'].isin(top_five_powers)]
# Out:
#                       Country          Sex   80_above   70to79   60to69   \
# 303  United States of America   Both sexes       25.1     18.4      17.9
# 304  United States of America         Male       49.7     32.5      27.9
# 305  United States of America       Female        9.6      6.6       8.8
#
#       50to59    40to49   30to39   20to29   10to19  Year  Mental _hospitals  \
# 303      21.7     19.3     19.2     18.0      6.3  2016              0.189
# 304      32.0     28.5     29.4     28.9      9.0  2016              0.189
# 305      11.6     10.1      9.0      6.6      3.4  2016              0.189
#
#      health_units  outpatient _facilities  day _treatment  \
# 303         0.349                   0.373        0.957612
# 304         0.349                   0.373        0.957612
# 305         0.349                   0.373        0.957612
#
#      residential_facilities
# 303                0.762909
# 304                0.762909
# 305                0.762909

# %%
male_df['mean'] = male_df.mean(axis=1)
# Out:
# <ipython-input-212-94b1a0221407>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   male_df['mean'] = male_df.mean(axis=1)

# %%
male_df.sort_values(by="mean", ascending=False)
# Out:
#                  Country    Sex   80_above   70to79   60to69    50to59   \
# 547             Zimbabwe   Male      285.0    111.5      62.8      47.0
# 289            Lithuania   Male      126.6     81.6      78.5      85.4
# 118        Côte d'Ivoire   Male      202.6    123.2      67.3      45.5
# 406   Russian Federation   Male      101.0     76.6      61.4      72.4
# 211               Guyana   Male       91.4     53.6      52.1      73.8
# ..                   ...    ...        ...      ...       ...       ...
# 367             Pakistan   Male        7.5      4.0       3.2       3.2
# 199              Grenada   Male        0.0      0.0      29.4       0.0
# 40              Barbados   Male       26.6      0.0       0.0       0.6
# 265               Kuwait   Male        0.0      0.0       4.0       3.7
# 13   Antigua and Barbuda   Male        0.0      0.0       0.0       0.0
#
#       40to49   30to39   20to29   10to19     mean
# 547     30.1     22.8     19.1      6.4  73.0875
# ...

# %%
female_df['mean'] = female_df.mean(axis=1)
# Out:
# <ipython-input-219-813bc9b975df>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female_df['mean'] = female_df.mean(axis=1)

# %%
female_df.sort_values(by="mean", ascending=False)
# Out:
#                                 Country      Sex   80_above   70to79  \
# 281                             Lesotho   Female      210.4    133.7
# 509                              Uganda   Female      137.2    107.0
# 359                             Nigeria   Female      123.9     98.6
# 284                             Liberia   Female      126.0     97.1
# 548                            Zimbabwe   Female      152.4     59.4
# ..                                  ...      ...        ...      ...
# 536  Venezuela (Bolivarian Republic of)   Female        2.2      2.7
# 515                United Arab Emirates   Female        3.3      1.4
# 41                             Barbados   Female        0.0      7.8
# 32                              Bahamas   Female        2.4      1.3
# 416    Saint Vincent and the Grenadines   Female        0.0      0.0
#
#       60to69    50to59    40to49   30to39   20to29   10to19     mean
# 281      69.9      56.9     40.7     26.9     19.1     10.6  71.0250
# ...

# %%
population_df = pd.read_csv('data/raw/population_by_country_2020.csv')

# %%
df['mean'] = df.mean(axis = 1)

# %%
df.sort_values(by="mean", ascending=False)
# Out:
#                               Country          Sex   80_above   70to79  \
# 547                          Zimbabwe         Male      285.0    111.5
# 289                         Lithuania         Male      126.6     81.6
# 281                           Lesotho       Female      210.4    133.7
# 118                     Côte d'Ivoire         Male      202.6    123.2
# 406                Russian Federation         Male      101.0     76.6
# ..                                ...          ...        ...      ...
# 12                Antigua and Barbuda   Both sexes        0.0      0.0
# 41                           Barbados       Female        0.0      7.8
# 32                            Bahamas       Female        2.4      1.3
# 416  Saint Vincent and the Grenadines       Female        0.0      0.0
# 13                Antigua and Barbuda         Male        0.0      0.0
#
#       60to69    50to59    40to49   30to39   20to29   10to19     mean
# ...

# %%
gross_population_suicide_rate_df = pd.merge(population_df[["Population (2020)","Country"]], df, on='Country')

# %%
gross_population_suicide_rate_df
# Out:
#      Population (2020)              Country          Sex   80_above   70to79  \
# 0           1440297825                China   Both sexes       61.3     44.0
# 1           1440297825                China         Male       73.2     51.2
# 2           1440297825                China       Female       52.3     37.1
# 3           1382345085                India   Both sexes       24.5     21.9
# 4           1382345085                India         Male       37.7     25.3
# ..                 ...                  ...          ...        ...      ...
# 484              98453           Seychelles         Male       47.8     35.2
# 485              98453           Seychelles       Female       14.3      5.9
# 486              98069  Antigua and Barbuda   Both sexes        0.0      0.0
# 487              98069  Antigua and Barbuda         Male        0.0      0.0
# 488              98069  Antigua and Barbuda       Female        0.0      0.0
#
# ...

# %%
gross_population_suicide_rate_df['average_number_of_suicides'] = (gross_population_suicide_rate_df["Population (2020)"] / 100000.0) * gross_population_suicide_rate_df["mean"]

# %%
gross_population_suicide_rate_df
# Out:
#      Population (2020)              Country          Sex   80_above   70to79  \
# 0           1440297825                China   Both sexes       61.3     44.0
# 1           1440297825                China         Male       73.2     51.2
# 2           1440297825                China       Female       52.3     37.1
# 3           1382345085                India   Both sexes       24.5     21.9
# 4           1382345085                India         Male       37.7     25.3
# ..                 ...                  ...          ...        ...      ...
# 484              98453           Seychelles         Male       47.8     35.2
# 485              98453           Seychelles       Female       14.3      5.9
# 486              98069  Antigua and Barbuda   Both sexes        0.0      0.0
# 487              98069  Antigua and Barbuda         Male        0.0      0.0
# 488              98069  Antigua and Barbuda       Female        0.0      0.0
#
# ...

# %%
population_vs_average_suicides = gross_population_suicide_rate_df[gross_population_suicide_rate_df['Sex'].isin([' Both sexes'])]

# %%
top_10_countries_by_suicide = population_vs_average_suicides[["Country", "average_number_of_suicides", "Population (2020)"]].sort_values(by="average_number_of_suicides", ascending=False).head(10)

# %%
top_10_countries_by_suicide.plot(x="Country", y= ["average_number_of_suicides"], kind="bar")
# Out:
# <AxesSubplot:xlabel='Country'>

# %%
gross_population_suicide_rate_df['suicide rate vs population'] = gross_population_suicide_rate_df["average_number_of_suicides"] / gross_population_suicide_rate_df["Population (2020)"]

# %%
gross_population_suicide_rate_df
# Out:
#      Population (2020)              Country          Sex   80_above   70to79  \
# 0           1440297825                China   Both sexes       61.3     44.0
# 1           1440297825                China         Male       73.2     51.2
# 2           1440297825                China       Female       52.3     37.1
# 3           1382345085                India   Both sexes       24.5     21.9
# 4           1382345085                India         Male       37.7     25.3
# ..                 ...                  ...          ...        ...      ...
# 484              98453           Seychelles         Male       47.8     35.2
# 485              98453           Seychelles       Female       14.3      5.9
# 486              98069  Antigua and Barbuda   Both sexes        0.0      0.0
# 487              98069  Antigua and Barbuda         Male        0.0      0.0
# 488              98069  Antigua and Barbuda       Female        0.0      0.0
#
# ...

# %%
top_10_countries_by_suicide.sort_values("Population (2020)", ascending=False).plot(x="Country", y= "Population (2020)", kind="bar")
# Out:
# <AxesSubplot:xlabel='Country'>
